# %% [markdown]
# # Multiple Choice Classifier
#
# Purpose of this notebook is to process and train a decision tree classifier for all multiple choice features on users profiles. An extra feature I'd like to explore is explainable AI - would be nice to explain to the user which features effected the resulting match percentage.

# %%
import pandas as pd
import json

f = open('data/bumble.json')
profiles = json.load(f)

profiles[0]

# Function to transform the array of objects into a DataFrame
def transform_data_to_dataframe(data):
    # Prepare an empty list to collect rows
    rows = []
    
    # Iterate through each object in the data
    for obj in data:
        # Extract the required information
        row = {
            'age': obj['age'].strip(),
            'isVerified': obj['isVerified'],
            'location_distance': obj['location']['distance'],
            'liked': obj['liked']
        }
        
        # Flatten the attributes into individual columns
        for attr in obj['attributes']:
            row[attr['type']] = attr['value']
            
        # Append the row to the list of rows
        rows.append(row)
    
    # Create a DataFrame from the rows
    df = pd.DataFrame(rows)
    
    return df

df = transform_data_to_dataframe(profiles)
df.head()
# Out:
#   age  isVerified location_distance  liked  height      exercise gender  \
# 0  20       False       ~36 km away  False  168 cm     Sometimes  Woman
# 1  19       False       ~12 km away  False     NaN  Almost never  Woman
# 2  19        True       ~14 km away   True  165 cm        Active  Woman
# 3  22        True                    False  170 cm  Almost never    NaN
# 4  24        True                    False  170 cm        Active  Woman
#
#        intentions   familyPlans  drinking   smoking  cannabis starSign  \
# 0  Don’t know yet  Not sure yet       NaN       NaN       NaN      NaN
# 1             NaN           NaN    Rarely     Never     Never   Pisces
# 2  Don’t know yet  Not sure yet  Socially  Socially  Socially      Leo
# 3  Don’t know yet  Not sure yet  Socially  Socially       NaN      NaN
# 4             NaN           NaN  Socially     Never       NaN      NaN
#
#     religion Politics       education
# 0        NaN      NaN             NaN
# 1  Christian      NaN             NaN
# 2    Atheist     Left             NaN
# 3        NaN      NaN             NaN
# 4        NaN      NaN  I’m a postgrad

# %% [markdown]
# Lets process some of these fields

# %%
# reformat location_distance to be a numerical feature
df['location_distance'] = pd.to_numeric(df['location_distance'].str.replace('~', '').str.replace('km away', '').str.strip(), errors='coerce')

# reformat height to be a numerical feature
df['height'] = pd.to_numeric(df['height'].str.replace('cm', '').str.strip(), errors='coerce')

# convert age to type float
df['age'] = pd.to_numeric(df['age'], errors='coerce')

# replace NaN values with mean - only height and age, dont think it will hurt the model much
df['location_distance'].fillna(df['location_distance'].mean(), inplace=True)
df['height'].fillna(df['height'].mean(), inplace=True)

df.head()
# Out:
#    age  isVerified  location_distance  liked      height      exercise gender  \
# 0   20       False          36.000000  False  168.000000     Sometimes  Woman
# 1   19       False          12.000000  False  169.893805  Almost never  Woman
# 2   19        True          14.000000   True  165.000000        Active  Woman
# 3   22        True          20.396825  False  170.000000  Almost never    NaN
# 4   24        True          20.396825  False  170.000000        Active  Woman
#
#        intentions   familyPlans  drinking   smoking  cannabis starSign  \
# 0  Don’t know yet  Not sure yet       NaN       NaN       NaN      NaN
# 1             NaN           NaN    Rarely     Never     Never   Pisces
# 2  Don’t know yet  Not sure yet  Socially  Socially  Socially      Leo
# 3  Don’t know yet  Not sure yet  Socially  Socially       NaN      NaN
# 4             NaN           NaN  Socially     Never       NaN      NaN
#
#     religion Politics       education
# 0        NaN      NaN             NaN
# 1  Christian      NaN             NaN
# 2    Atheist     Left             NaN
# 3        NaN      NaN             NaN
# 4        NaN      NaN  I’m a postgrad

# %%
df.dtypes
# Out:
# age                    int64
# isVerified              bool
# location_distance    float64
# liked                   bool
# height               float64
# exercise              object
# gender                object
# intentions            object
# familyPlans           object
# drinking              object
# smoking               object
# cannabis              object
# starSign              object
# religion              object
# Politics              object
# education             object
# dtype: object

# %% [markdown]
# Now lets apply min max scalar to our numerical features

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

numerical_features = ['age', 'height', 'location_distance']
numerical_df = df[numerical_features]

scaled_numerical_df = pd.DataFrame(scaler.fit_transform(numerical_df), columns=numerical_features)

for feature in numerical_features:
    df[feature] = scaled_numerical_df[feature]
    
df.head()
# Out:
# c:\Users\henry\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\henry\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\henry\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\henry\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\henry\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\henry\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
#         age  isVerified  location_distance  liked    height      exercise  \
# 0  0.142857       False           0.772727  False  0.406250     Sometimes
# 1  0.000000       False           0.227273  False  0.465431  Almost never
# 2  0.000000        True           0.272727   True  0.312500        Active
# 3  0.428571        True           0.418110  False  0.468750  Almost never
# 4  0.714286        True           0.418110  False  0.468750        Active
#
#   gender      intentions   familyPlans  drinking   smoking  cannabis starSign  \
# 0  Woman  Don’t know yet  Not sure yet       NaN       NaN       NaN      NaN
# 1  Woman             NaN           NaN    Rarely     Never     Never   Pisces
# 2  Woman  Don’t know yet  Not sure yet  Socially  Socially  Socially      Leo
# 3    NaN  Don’t know yet  Not sure yet  Socially  Socially       NaN      NaN
# 4  Woman             NaN           NaN  Socially     Never       NaN      NaN
#
#     religion Politics       education
# 0        NaN      NaN             NaN
# 1  Christian      NaN             NaN
# 2    Atheist     Left             NaN
# 3        NaN      NaN             NaN
# 4        NaN      NaN  I’m a postgrad

# %% [markdown]
# Now lets apply one hot encoding to our textual features

# %%
# before we do this, lets convert the boolean features to strings 
textual_cols = df.select_dtypes(include=['object']).columns.tolist()

df_encoded = pd.get_dummies(df, columns=textual_cols)
df_encoded.head()
# Out:
#         age  isVerified  location_distance  liked    height  exercise_Active  \
# 0  0.142857       False           0.772727  False  0.406250            False
# 1  0.000000       False           0.227273  False  0.465431            False
# 2  0.000000        True           0.272727   True  0.312500             True
# 3  0.428571        True           0.418110  False  0.468750            False
# 4  0.714286        True           0.418110  False  0.468750             True
#
#    exercise_Almost never  exercise_Sometimes  gender_Trans woman  \
# 0                  False                True               False
# 1                   True               False               False
# 2                  False               False               False
# 3                   True               False               False
# 4                  False               False               False
#
#    gender_Woman  ...  Politics_Apolitical  Politics_Left  Politics_Liberal  \
# 0          True  ...                False          False             False
# 1          True  ...                False          False             False
# 2          True  ...                False           True             False
# 3         False  ...                False          False             False
# 4          True  ...                False          False             False
#
#    Politics_Moderate  education_I’m a postgrad  education_I’m an undergrad  \
# 0              False                     False                       False
# 1              False                     False                       False
# 2              False                     False                       False
# 3              False                     False                       False
# 4              False                      True                       False
#
#    education_Postgraduate degree  education_Sixth form  \
# 0                          False                 False
# 1                          False                 False
# 2                          False                 False
# 3                          False                 False
# 4                          False                 False
#
#    education_Technical college  education_Undergraduate degree
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                           False
# 4                        False                           False
#
# [5 rows x 59 columns]

# %% [markdown]
# Cool, now lets train a model

# %%
df['liked'].value_counts(normalize=True) * 100
# Out:
# liked
# False    75.362319
# True     24.637681
# Name: proportion, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report

# Dropping the 'liked' column from features since it's the target variable, and we already encoded it
X = df_encoded.drop(columns=['liked', 'age', 'height', 'location_distance'])
y = df_encoded['liked'] 

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize and train the Decision Tree Classifier
clf = GradientBoostingClassifier(random_state=42)
clf.fit(X_train, y_train)

# Predict on the test set
y_pred = clf.predict(X_test)

report = classification_report(y_test, y_pred, target_names=['False', 'True'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.78      0.97      0.86        32
#         True       0.50      0.10      0.17        10
#
#     accuracy                           0.76        42
#    macro avg       0.64      0.53      0.51        42
# weighted avg       0.71      0.76      0.70        42
# c:\Users\henry\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\henry\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
